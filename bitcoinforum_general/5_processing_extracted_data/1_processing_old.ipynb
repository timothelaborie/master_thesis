# %%
import pandas as pd
import os
import gzip
import pickle
import openai
import re
import copy
from tqdm import tqdm
from torch import save,load
import time
import json

# %%
df = pd.read_csv('outputs/outputs_chunk_1.csv')

# %%
print(df.iloc[3]["output"]) #example: ```json{  "categories": [     "optimistic_speculation","altcoins"
# Out:
# ```json
# {
#   "categories": [
#     "bitcoin_technology",
#     "bitcoin_mining"

# %%
all_categories = ["optimistic_speculation", "pessimistic_speculation", "bitcoin_adoption", "bitcoin_technology", "financial_products", "bitcoin_challenges", "scams", "bitcoin_mining", "altcoins", "educational_resources", "other"]

categories = ["optimistic_speculation", "pessimistic_speculation", "bitcoin_adoption", "bitcoin_technology", "bitcoin_challenges", "altcoins", "educational_resources"]



months = {}

# for i in range(1, 14):
for (i,file) in enumerate(os.listdir('outputs/')):
    i = i+1
    # print(i)
    df = pd.read_csv('outputs/' + file)
    for row in df.iterrows():
        row = row[1]
        index = row["index"]
        date = row["date"] # 2010-01-01 21:46:38
        output = row["output"]
        jsonoutput = output.replace("```json", "")+"]}"
        parsed = json.loads(jsonoutput)

        # for each month, get the sum of instances of each category
        month = str(date)[:7]
        if month == "nan":
            print(f"nan found, index: {index} date: {date} output: {output}")
            continue
        if month not in months:
            months[month] = {category: 0 for category in categories}
        for category in categories:
            if category in parsed["categories"]:
                months[month][category] += 1
# Out:
# nan found, index: nan date: nan output: ```json
# {
#   "categories": [
#     "other"
# nan found, index: nan date: nan output: ```json
# {
#   "categories": [
#     "other"

# %%
months
# Out:
# {'2010-01': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 0,
#   'bitcoin_technology': 6,
#   'bitcoin_challenges': 1,
#   'altcoins': 0,
#   'educational_resources': 8},
#  '2010-02': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 0,
#   'bitcoin_technology': 9,
#   'bitcoin_challenges': 1,
#   'altcoins': 0,
#   'educational_resources': 9},
#  '2010-03': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 1,
#   'bitcoin_technology': 4,
#   'bitcoin_challenges': 1,
#   'altcoins': 0,
#   'educational_resources': 5},
#  '2010-04': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 0,
#   'bitcoin_technology': 4,
#   'bitcoin_challenges': 3,
#   'altcoins': 1,
#   'educational_resources': 4},
#  '2010-05': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 1,
#   'bitcoin_technology': 0,
#   'bitcoin_challenges': 1,
#   'altcoins': 0,
#   'educational_resources': 2},
#  '2010-06': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 1,
#   'bitcoin_technology': 5,
#   'bitcoin_challenges': 5,
#   'altcoins': 0,
#   'educational_resources': 8},
#  '2010-07': {'optimistic_speculation': 1,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 1,
#   'bitcoin_technology': 53,
#   'bitcoin_challenges': 24,
#   'altcoins': 0,
#   'educational_resources': 48},
#  '2010-08': {'optimistic_speculation': 1,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 2,
#   'bitcoin_technology': 47,
#   'bitcoin_challenges': 26,
#   'altcoins': 6,
#   'educational_resources': 41},
#  '2011-05': {'optimistic_speculation': 11,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 36,
#   'bitcoin_technology': 188,
#   'bitcoin_challenges': 137,
#   'altcoins': 14,
#   'educational_resources': 273},
#  '2011-06': {'optimistic_speculation': 108,
#   'pessimistic_speculation': 75,
#   'bitcoin_adoption': 83,
#   'bitcoin_technology': 438,
#   'bitcoin_challenges': 537,
#   'altcoins': 38,
#   'educational_resources': 669},
#  '2014-10': {'optimistic_speculation': 15,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 62,
#   'bitcoin_technology': 151,
#   'bitcoin_challenges': 140,
#   'altcoins': 27,
#   'educational_resources': 205},
#  '2014-11': {'optimistic_speculation': 12,
#   'pessimistic_speculation': 4,
#   'bitcoin_adoption': 52,
#   'bitcoin_technology': 85,
#   'bitcoin_challenges': 71,
#   'altcoins': 5,
#   'educational_resources': 146},
#  '2014-12': {'optimistic_speculation': 15,
#   'pessimistic_speculation': 4,
#   'bitcoin_adoption': 73,
#   'bitcoin_technology': 95,
#   'bitcoin_challenges': 76,
#   'altcoins': 20,
#   'educational_resources': 175},
#  '2015-01': {'optimistic_speculation': 36,
#   'pessimistic_speculation': 22,
#   'bitcoin_adoption': 50,
#   'bitcoin_technology': 117,
#   'bitcoin_challenges': 137,
#   'altcoins': 22,
#   'educational_resources': 170},
#  '2015-02': {'optimistic_speculation': 19,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 79,
#   'bitcoin_technology': 92,
#   'bitcoin_challenges': 126,
#   'altcoins': 22,
#   'educational_resources': 145},
#  '2015-03': {'optimistic_speculation': 13,
#   'pessimistic_speculation': 4,
#   'bitcoin_adoption': 51,
#   'bitcoin_technology': 107,
#   'bitcoin_challenges': 84,
#   'altcoins': 15,
#   'educational_resources': 149},
#  '2015-04': {'optimistic_speculation': 14,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 54,
#   'bitcoin_technology': 93,
#   'bitcoin_challenges': 94,
#   'altcoins': 23,
#   'educational_resources': 126},
#  '2015-05': {'optimistic_speculation': 11,
#   'pessimistic_speculation': 4,
#   'bitcoin_adoption': 30,
#   'bitcoin_technology': 119,
#   'bitcoin_challenges': 90,
#   'altcoins': 23,
#   'educational_resources': 123},
#  '2015-06': {'optimistic_speculation': 16,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 43,
#   'bitcoin_technology': 149,
#   'bitcoin_challenges': 110,
#   'altcoins': 22,
#   'educational_resources': 116},
#  '2015-07': {'optimistic_speculation': 22,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 59,
#   'bitcoin_technology': 166,
#   'bitcoin_challenges': 136,
#   'altcoins': 21,
#   'educational_resources': 194},
#  '2015-08': {'optimistic_speculation': 17,
#   'pessimistic_speculation': 8,
#   'bitcoin_adoption': 43,
#   'bitcoin_technology': 275,
#   'bitcoin_challenges': 217,
#   'altcoins': 25,
#   'educational_resources': 185},
#  '2015-09': {'optimistic_speculation': 12,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 22,
#   'bitcoin_technology': 155,
#   'bitcoin_challenges': 136,
#   'altcoins': 10,
#   'educational_resources': 102},
#  '2015-10': {'optimistic_speculation': 9,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 42,
#   'bitcoin_technology': 99,
#   'bitcoin_challenges': 84,
#   'altcoins': 12,
#   'educational_resources': 122},
#  '2015-11': {'optimistic_speculation': 21,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 35,
#   'bitcoin_technology': 110,
#   'bitcoin_challenges': 80,
#   'altcoins': 16,
#   'educational_resources': 130},
#  '2015-12': {'optimistic_speculation': 18,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 25,
#   'bitcoin_technology': 124,
#   'bitcoin_challenges': 76,
#   'altcoins': 15,
#   'educational_resources': 126},
#  '2016-01': {'optimistic_speculation': 15,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 44,
#   'bitcoin_technology': 185,
#   'bitcoin_challenges': 172,
#   'altcoins': 26,
#   'educational_resources': 156},
#  '2016-02': {'optimistic_speculation': 11,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 37,
#   'bitcoin_technology': 167,
#   'bitcoin_challenges': 116,
#   'altcoins': 18,
#   'educational_resources': 166},
#  '2016-03': {'optimistic_speculation': 11,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 23,
#   'bitcoin_technology': 131,
#   'bitcoin_challenges': 98,
#   'altcoins': 21,
#   'educational_resources': 101},
#  '2016-04': {'optimistic_speculation': 13,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 43,
#   'bitcoin_technology': 101,
#   'bitcoin_challenges': 60,
#   'altcoins': 15,
#   'educational_resources': 119},
#  '2016-05': {'optimistic_speculation': 18,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 35,
#   'bitcoin_technology': 131,
#   'bitcoin_challenges': 89,
#   'altcoins': 20,
#   'educational_resources': 144},
#  '2016-06': {'optimistic_speculation': 30,
#   'pessimistic_speculation': 8,
#   'bitcoin_adoption': 44,
#   'bitcoin_technology': 109,
#   'bitcoin_challenges': 97,
#   'altcoins': 25,
#   'educational_resources': 139},
#  '2016-07': {'optimistic_speculation': 28,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 37,
#   'bitcoin_technology': 96,
#   'bitcoin_challenges': 83,
#   'altcoins': 18,
#   'educational_resources': 130},
#  '2016-08': {'optimistic_speculation': 10,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 21,
#   'bitcoin_technology': 96,
#   'bitcoin_challenges': 77,
#   'altcoins': 23,
#   'educational_resources': 140},
#  '2016-09': {'optimistic_speculation': 9,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 20,
#   'bitcoin_technology': 79,
#   'bitcoin_challenges': 55,
#   'altcoins': 22,
#   'educational_resources': 92},
#  '2016-10': {'optimistic_speculation': 9,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 38,
#   'bitcoin_technology': 92,
#   'bitcoin_challenges': 65,
#   'altcoins': 16,
#   'educational_resources': 105},
#  '2016-11': {'optimistic_speculation': 12,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 34,
#   'bitcoin_technology': 105,
#   'bitcoin_challenges': 81,
#   'altcoins': 12,
#   'educational_resources': 96},
#  '2016-12': {'optimistic_speculation': 11,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 23,
#   'bitcoin_technology': 92,
#   'bitcoin_challenges': 76,
#   'altcoins': 13,
#   'educational_resources': 110},
#  '2017-01': {'optimistic_speculation': 12,
#   'pessimistic_speculation': 8,
#   'bitcoin_adoption': 39,
#   'bitcoin_technology': 129,
#   'bitcoin_challenges': 116,
#   'altcoins': 19,
#   'educational_resources': 145},
#  '2017-02': {'optimistic_speculation': 15,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 40,
#   'bitcoin_technology': 148,
#   'bitcoin_challenges': 142,
#   'altcoins': 22,
#   'educational_resources': 128},
#  '2017-03': {'optimistic_speculation': 35,
#   'pessimistic_speculation': 14,
#   'bitcoin_adoption': 31,
#   'bitcoin_technology': 304,
#   'bitcoin_challenges': 295,
#   'altcoins': 74,
#   'educational_resources': 176},
#  '2017-04': {'optimistic_speculation': 11,
#   'pessimistic_speculation': 10,
#   'bitcoin_adoption': 39,
#   'bitcoin_technology': 188,
#   'bitcoin_challenges': 165,
#   'altcoins': 29,
#   'educational_resources': 103},
#  '2017-05': {'optimistic_speculation': 47,
#   'pessimistic_speculation': 18,
#   'bitcoin_adoption': 52,
#   'bitcoin_technology': 197,
#   'bitcoin_challenges': 192,
#   'altcoins': 63,
#   'educational_resources': 158},
#  '2017-06': {'optimistic_speculation': 43,
#   'pessimistic_speculation': 23,
#   'bitcoin_adoption': 49,
#   'bitcoin_technology': 190,
#   'bitcoin_challenges': 201,
#   'altcoins': 64,
#   'educational_resources': 180},
#  '2017-07': {'optimistic_speculation': 56,
#   'pessimistic_speculation': 35,
#   'bitcoin_adoption': 44,
#   'bitcoin_technology': 320,
#   'bitcoin_challenges': 255,
#   'altcoins': 95,
#   'educational_resources': 268},
#  '2017-08': {'optimistic_speculation': 88,
#   'pessimistic_speculation': 21,
#   'bitcoin_adoption': 67,
#   'bitcoin_technology': 274,
#   'bitcoin_challenges': 248,
#   'altcoins': 98,
#   'educational_resources': 252},
#  '2017-09': {'optimistic_speculation': 118,
#   'pessimistic_speculation': 86,
#   'bitcoin_adoption': 103,
#   'bitcoin_technology': 189,
#   'bitcoin_challenges': 348,
#   'altcoins': 95,
#   'educational_resources': 301},
#  '2017-10': {'optimistic_speculation': 137,
#   'pessimistic_speculation': 54,
#   'bitcoin_adoption': 122,
#   'bitcoin_technology': 358,
#   'bitcoin_challenges': 358,
#   'altcoins': 159,
#   'educational_resources': 435},
#  '2017-11': {'optimistic_speculation': 313,
#   'pessimistic_speculation': 159,
#   'bitcoin_adoption': 156,
#   'bitcoin_technology': 411,
#   'bitcoin_challenges': 575,
#   'altcoins': 292,
#   'educational_resources': 562},
#  '2017-12': {'optimistic_speculation': 345,
#   'pessimistic_speculation': 200,
#   'bitcoin_adoption': 132,
#   'bitcoin_technology': 474,
#   'bitcoin_challenges': 670,
#   'altcoins': 311,
#   'educational_resources': 782},
#  '2018-01': {'optimistic_speculation': 263,
#   'pessimistic_speculation': 159,
#   'bitcoin_adoption': 146,
#   'bitcoin_technology': 418,
#   'bitcoin_challenges': 622,
#   'altcoins': 304,
#   'educational_resources': 710},
#  '2010-09': {'optimistic_speculation': 0,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 1,
#   'bitcoin_technology': 18,
#   'bitcoin_challenges': 9,
#   'altcoins': 2,
#   'educational_resources': 23},
#  '2010-10': {'optimistic_speculation': 2,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 7,
#   'bitcoin_technology': 18,
#   'bitcoin_challenges': 10,
#   'altcoins': 2,
#   'educational_resources': 25},
#  '2010-11': {'optimistic_speculation': 1,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 8,
#   'bitcoin_technology': 49,
#   'bitcoin_challenges': 17,
#   'altcoins': 3,
#   'educational_resources': 60},
#  '2011-07': {'optimistic_speculation': 28,
#   'pessimistic_speculation': 23,
#   'bitcoin_adoption': 71,
#   'bitcoin_technology': 190,
#   'bitcoin_challenges': 180,
#   'altcoins': 13,
#   'educational_resources': 298},
#  '2018-02': {'optimistic_speculation': 252,
#   'pessimistic_speculation': 170,
#   'bitcoin_adoption': 166,
#   'bitcoin_technology': 280,
#   'bitcoin_challenges': 452,
#   'altcoins': 226,
#   'educational_resources': 556},
#  '2018-03': {'optimistic_speculation': 233,
#   'pessimistic_speculation': 164,
#   'bitcoin_adoption': 196,
#   'bitcoin_technology': 284,
#   'bitcoin_challenges': 445,
#   'altcoins': 221,
#   'educational_resources': 580},
#  '2018-04': {'optimistic_speculation': 171,
#   'pessimistic_speculation': 88,
#   'bitcoin_adoption': 101,
#   'bitcoin_technology': 151,
#   'bitcoin_challenges': 251,
#   'altcoins': 112,
#   'educational_resources': 324},
#  '2018-05': {'optimistic_speculation': 64,
#   'pessimistic_speculation': 40,
#   'bitcoin_adoption': 55,
#   'bitcoin_technology': 132,
#   'bitcoin_challenges': 163,
#   'altcoins': 85,
#   'educational_resources': 193},
#  '2018-06': {'optimistic_speculation': 54,
#   'pessimistic_speculation': 43,
#   'bitcoin_adoption': 61,
#   'bitcoin_technology': 83,
#   'bitcoin_challenges': 127,
#   'altcoins': 58,
#   'educational_resources': 147},
#  '2018-07': {'optimistic_speculation': 93,
#   'pessimistic_speculation': 27,
#   'bitcoin_adoption': 90,
#   'bitcoin_technology': 99,
#   'bitcoin_challenges': 144,
#   'altcoins': 41,
#   'educational_resources': 172},
#  '2018-08': {'optimistic_speculation': 97,
#   'pessimistic_speculation': 45,
#   'bitcoin_adoption': 67,
#   'bitcoin_technology': 95,
#   'bitcoin_challenges': 145,
#   'altcoins': 62,
#   'educational_resources': 166},
#  '2018-09': {'optimistic_speculation': 68,
#   'pessimistic_speculation': 38,
#   'bitcoin_adoption': 67,
#   'bitcoin_technology': 89,
#   'bitcoin_challenges': 109,
#   'altcoins': 39,
#   'educational_resources': 137},
#  '2018-10': {'optimistic_speculation': 40,
#   'pessimistic_speculation': 18,
#   'bitcoin_adoption': 67,
#   'bitcoin_technology': 83,
#   'bitcoin_challenges': 93,
#   'altcoins': 27,
#   'educational_resources': 127},
#  '2018-11': {'optimistic_speculation': 48,
#   'pessimistic_speculation': 42,
#   'bitcoin_adoption': 44,
#   'bitcoin_technology': 62,
#   'bitcoin_challenges': 123,
#   'altcoins': 43,
#   'educational_resources': 103},
#  '2011-08': {'optimistic_speculation': 17,
#   'pessimistic_speculation': 14,
#   'bitcoin_adoption': 25,
#   'bitcoin_technology': 154,
#   'bitcoin_challenges': 138,
#   'altcoins': 16,
#   'educational_resources': 229},
#  '2018-12': {'optimistic_speculation': 42,
#   'pessimistic_speculation': 19,
#   'bitcoin_adoption': 24,
#   'bitcoin_technology': 64,
#   'bitcoin_challenges': 105,
#   'altcoins': 22,
#   'educational_resources': 91},
#  '2019-01': {'optimistic_speculation': 36,
#   'pessimistic_speculation': 15,
#   'bitcoin_adoption': 35,
#   'bitcoin_technology': 55,
#   'bitcoin_challenges': 62,
#   'altcoins': 13,
#   'educational_resources': 94},
#  '2019-02': {'optimistic_speculation': 12,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 32,
#   'bitcoin_technology': 51,
#   'bitcoin_challenges': 41,
#   'altcoins': 13,
#   'educational_resources': 69},
#  '2019-03': {'optimistic_speculation': 20,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 17,
#   'bitcoin_technology': 55,
#   'bitcoin_challenges': 43,
#   'altcoins': 13,
#   'educational_resources': 72},
#  '2019-04': {'optimistic_speculation': 26,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 27,
#   'bitcoin_technology': 57,
#   'bitcoin_challenges': 56,
#   'altcoins': 21,
#   'educational_resources': 80},
#  '2019-05': {'optimistic_speculation': 53,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 45,
#   'bitcoin_technology': 81,
#   'bitcoin_challenges': 83,
#   'altcoins': 23,
#   'educational_resources': 129},
#  '2019-06': {'optimistic_speculation': 32,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 35,
#   'bitcoin_technology': 77,
#   'bitcoin_challenges': 81,
#   'altcoins': 19,
#   'educational_resources': 114},
#  '2019-07': {'optimistic_speculation': 36,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 41,
#   'bitcoin_technology': 56,
#   'bitcoin_challenges': 73,
#   'altcoins': 26,
#   'educational_resources': 108},
#  '2019-08': {'optimistic_speculation': 20,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 35,
#   'bitcoin_technology': 38,
#   'bitcoin_challenges': 51,
#   'altcoins': 20,
#   'educational_resources': 79},
#  '2019-09': {'optimistic_speculation': 17,
#   'pessimistic_speculation': 18,
#   'bitcoin_adoption': 24,
#   'bitcoin_technology': 47,
#   'bitcoin_challenges': 38,
#   'altcoins': 9,
#   'educational_resources': 83},
#  '2019-10': {'optimistic_speculation': 37,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 50,
#   'bitcoin_technology': 61,
#   'bitcoin_challenges': 74,
#   'altcoins': 23,
#   'educational_resources': 117},
#  '2019-11': {'optimistic_speculation': 35,
#   'pessimistic_speculation': 16,
#   'bitcoin_adoption': 52,
#   'bitcoin_technology': 60,
#   'bitcoin_challenges': 80,
#   'altcoins': 16,
#   'educational_resources': 110},
#  '2019-12': {'optimistic_speculation': 42,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 42,
#   'bitcoin_technology': 56,
#   'bitcoin_challenges': 61,
#   'altcoins': 14,
#   'educational_resources': 88},
#  '2020-01': {'optimistic_speculation': 28,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 32,
#   'bitcoin_technology': 58,
#   'bitcoin_challenges': 53,
#   'altcoins': 12,
#   'educational_resources': 107},
#  '2020-02': {'optimistic_speculation': 19,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 19,
#   'bitcoin_technology': 47,
#   'bitcoin_challenges': 37,
#   'altcoins': 12,
#   'educational_resources': 93},
#  '2020-03': {'optimistic_speculation': 33,
#   'pessimistic_speculation': 20,
#   'bitcoin_adoption': 38,
#   'bitcoin_technology': 24,
#   'bitcoin_challenges': 43,
#   'altcoins': 5,
#   'educational_resources': 64},
#  '2020-04': {'optimistic_speculation': 29,
#   'pessimistic_speculation': 14,
#   'bitcoin_adoption': 19,
#   'bitcoin_technology': 34,
#   'bitcoin_challenges': 36,
#   'altcoins': 5,
#   'educational_resources': 70},
#  '2020-05': {'optimistic_speculation': 36,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 15,
#   'bitcoin_technology': 60,
#   'bitcoin_challenges': 53,
#   'altcoins': 14,
#   'educational_resources': 100},
#  '2020-06': {'optimistic_speculation': 22,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 33,
#   'bitcoin_technology': 57,
#   'bitcoin_challenges': 45,
#   'altcoins': 10,
#   'educational_resources': 94},
#  '2020-07': {'optimistic_speculation': 17,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 15,
#   'bitcoin_technology': 51,
#   'bitcoin_challenges': 39,
#   'altcoins': 10,
#   'educational_resources': 65},
#  '2020-08': {'optimistic_speculation': 33,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 23,
#   'bitcoin_technology': 45,
#   'bitcoin_challenges': 41,
#   'altcoins': 11,
#   'educational_resources': 77},
#  '2020-09': {'optimistic_speculation': 22,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 31,
#   'bitcoin_technology': 52,
#   'bitcoin_challenges': 54,
#   'altcoins': 14,
#   'educational_resources': 83},
#  '2020-10': {'optimistic_speculation': 40,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 34,
#   'bitcoin_technology': 51,
#   'bitcoin_challenges': 59,
#   'altcoins': 7,
#   'educational_resources': 90},
#  '2020-11': {'optimistic_speculation': 79,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 49,
#   'bitcoin_technology': 58,
#   'bitcoin_challenges': 77,
#   'altcoins': 15,
#   'educational_resources': 125},
#  '2020-12': {'optimistic_speculation': 79,
#   'pessimistic_speculation': 24,
#   'bitcoin_adoption': 38,
#   'bitcoin_technology': 57,
#   'bitcoin_challenges': 76,
#   'altcoins': 21,
#   'educational_resources': 120},
#  '2021-01': {'optimistic_speculation': 86,
#   'pessimistic_speculation': 28,
#   'bitcoin_adoption': 32,
#   'bitcoin_technology': 76,
#   'bitcoin_challenges': 82,
#   'altcoins': 26,
#   'educational_resources': 171},
#  '2021-02': {'optimistic_speculation': 73,
#   'pessimistic_speculation': 21,
#   'bitcoin_adoption': 50,
#   'bitcoin_technology': 40,
#   'bitcoin_challenges': 69,
#   'altcoins': 18,
#   'educational_resources': 94},
#  '2011-09': {'optimistic_speculation': 8,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 29,
#   'bitcoin_technology': 79,
#   'bitcoin_challenges': 60,
#   'altcoins': 6,
#   'educational_resources': 133},
#  '2021-03': {'optimistic_speculation': 32,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 34,
#   'bitcoin_technology': 52,
#   'bitcoin_challenges': 59,
#   'altcoins': 13,
#   'educational_resources': 90},
#  '2021-04': {'optimistic_speculation': 40,
#   'pessimistic_speculation': 21,
#   'bitcoin_adoption': 33,
#   'bitcoin_technology': 29,
#   'bitcoin_challenges': 60,
#   'altcoins': 17,
#   'educational_resources': 65},
#  '2021-05': {'optimistic_speculation': 42,
#   'pessimistic_speculation': 23,
#   'bitcoin_adoption': 26,
#   'bitcoin_technology': 47,
#   'bitcoin_challenges': 92,
#   'altcoins': 28,
#   'educational_resources': 67},
#  '2021-06': {'optimistic_speculation': 45,
#   'pessimistic_speculation': 14,
#   'bitcoin_adoption': 46,
#   'bitcoin_technology': 43,
#   'bitcoin_challenges': 91,
#   'altcoins': 16,
#   'educational_resources': 71},
#  '2021-07': {'optimistic_speculation': 26,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 27,
#   'bitcoin_technology': 53,
#   'bitcoin_challenges': 55,
#   'altcoins': 10,
#   'educational_resources': 67},
#  '2021-08': {'optimistic_speculation': 28,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 43,
#   'bitcoin_technology': 40,
#   'bitcoin_challenges': 50,
#   'altcoins': 10,
#   'educational_resources': 84},
#  '2021-09': {'optimistic_speculation': 22,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 45,
#   'bitcoin_technology': 47,
#   'bitcoin_challenges': 51,
#   'altcoins': 9,
#   'educational_resources': 78},
#  '2021-10': {'optimistic_speculation': 19,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 24,
#   'bitcoin_technology': 23,
#   'bitcoin_challenges': 34,
#   'altcoins': 8,
#   'educational_resources': 53},
#  '2021-11': {'optimistic_speculation': 14,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 20,
#   'bitcoin_technology': 27,
#   'bitcoin_challenges': 39,
#   'altcoins': 6,
#   'educational_resources': 48},
#  '2021-12': {'optimistic_speculation': 31,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 18,
#   'bitcoin_technology': 41,
#   'bitcoin_challenges': 39,
#   'altcoins': 10,
#   'educational_resources': 70},
#  '2022-01': {'optimistic_speculation': 32,
#   'pessimistic_speculation': 10,
#   'bitcoin_adoption': 28,
#   'bitcoin_technology': 33,
#   'bitcoin_challenges': 33,
#   'altcoins': 6,
#   'educational_resources': 73},
#  '2022-02': {'optimistic_speculation': 14,
#   'pessimistic_speculation': 10,
#   'bitcoin_adoption': 40,
#   'bitcoin_technology': 25,
#   'bitcoin_challenges': 50,
#   'altcoins': 3,
#   'educational_resources': 41},
#  '2022-03': {'optimistic_speculation': 26,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 47,
#   'bitcoin_technology': 33,
#   'bitcoin_challenges': 64,
#   'altcoins': 13,
#   'educational_resources': 79},
#  '2022-04': {'optimistic_speculation': 18,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 32,
#   'bitcoin_technology': 39,
#   'bitcoin_challenges': 39,
#   'altcoins': 10,
#   'educational_resources': 87},
#  '2022-05': {'optimistic_speculation': 20,
#   'pessimistic_speculation': 13,
#   'bitcoin_adoption': 29,
#   'bitcoin_technology': 34,
#   'bitcoin_challenges': 43,
#   'altcoins': 11,
#   'educational_resources': 70},
#  '2022-06': {'optimistic_speculation': 30,
#   'pessimistic_speculation': 32,
#   'bitcoin_adoption': 25,
#   'bitcoin_technology': 36,
#   'bitcoin_challenges': 56,
#   'altcoins': 18,
#   'educational_resources': 72},
#  '2022-07': {'optimistic_speculation': 30,
#   'pessimistic_speculation': 14,
#   'bitcoin_adoption': 26,
#   'bitcoin_technology': 44,
#   'bitcoin_challenges': 47,
#   'altcoins': 12,
#   'educational_resources': 85},
#  '2022-08': {'optimistic_speculation': 18,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 28,
#   'bitcoin_technology': 44,
#   'bitcoin_challenges': 39,
#   'altcoins': 7,
#   'educational_resources': 87},
#  '2022-09': {'optimistic_speculation': 18,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 25,
#   'bitcoin_technology': 33,
#   'bitcoin_challenges': 40,
#   'altcoins': 9,
#   'educational_resources': 71},
#  '2022-10': {'optimistic_speculation': 31,
#   'pessimistic_speculation': 10,
#   'bitcoin_adoption': 34,
#   'bitcoin_technology': 26,
#   'bitcoin_challenges': 38,
#   'altcoins': 6,
#   'educational_resources': 66},
#  '2022-11': {'optimistic_speculation': 31,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 20,
#   'bitcoin_technology': 36,
#   'bitcoin_challenges': 47,
#   'altcoins': 9,
#   'educational_resources': 79},
#  '2022-12': {'optimistic_speculation': 22,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 34,
#   'bitcoin_technology': 42,
#   'bitcoin_challenges': 40,
#   'altcoins': 9,
#   'educational_resources': 94},
#  '2023-01': {'optimistic_speculation': 37,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 33,
#   'bitcoin_technology': 46,
#   'bitcoin_challenges': 34,
#   'altcoins': 2,
#   'educational_resources': 96},
#  '2023-02': {'optimistic_speculation': 24,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 37,
#   'bitcoin_technology': 39,
#   'bitcoin_challenges': 58,
#   'altcoins': 9,
#   'educational_resources': 102},
#  '2011-10': {'optimistic_speculation': 14,
#   'pessimistic_speculation': 10,
#   'bitcoin_adoption': 36,
#   'bitcoin_technology': 80,
#   'bitcoin_challenges': 85,
#   'altcoins': 9,
#   'educational_resources': 137},
#  '2023-03': {'optimistic_speculation': 57,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 39,
#   'bitcoin_technology': 55,
#   'bitcoin_challenges': 57,
#   'altcoins': 17,
#   'educational_resources': 141},
#  '2023-04': {'optimistic_speculation': 53,
#   'pessimistic_speculation': 16,
#   'bitcoin_adoption': 36,
#   'bitcoin_technology': 51,
#   'bitcoin_challenges': 54,
#   'altcoins': 8,
#   'educational_resources': 133},
#  '2023-05': {'optimistic_speculation': 46,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 34,
#   'bitcoin_technology': 79,
#   'bitcoin_challenges': 84,
#   'altcoins': 16,
#   'educational_resources': 148},
#  '2023-06': {'optimistic_speculation': 24,
#   'pessimistic_speculation': 9,
#   'bitcoin_adoption': 29,
#   'bitcoin_technology': 33,
#   'bitcoin_challenges': 56,
#   'altcoins': 7,
#   'educational_resources': 109},
#  '2023-07': {'optimistic_speculation': 40,
#   'pessimistic_speculation': 4,
#   'bitcoin_adoption': 30,
#   'bitcoin_technology': 35,
#   'bitcoin_challenges': 37,
#   'altcoins': 9,
#   'educational_resources': 97},
#  '2023-08': {'optimistic_speculation': 45,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 29,
#   'bitcoin_technology': 34,
#   'bitcoin_challenges': 43,
#   'altcoins': 13,
#   'educational_resources': 91},
#  '2023-09': {'optimistic_speculation': 44,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 29,
#   'bitcoin_technology': 55,
#   'bitcoin_challenges': 64,
#   'altcoins': 12,
#   'educational_resources': 110},
#  '2023-10': {'optimistic_speculation': 53,
#   'pessimistic_speculation': 8,
#   'bitcoin_adoption': 23,
#   'bitcoin_technology': 53,
#   'bitcoin_challenges': 45,
#   'altcoins': 12,
#   'educational_resources': 128},
#  '2023-11': {'optimistic_speculation': 48,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 23,
#   'bitcoin_technology': 65,
#   'bitcoin_challenges': 64,
#   'altcoins': 12,
#   'educational_resources': 112},
#  '2023-12': {'optimistic_speculation': 50,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 24,
#   'bitcoin_technology': 69,
#   'bitcoin_challenges': 63,
#   'altcoins': 20,
#   'educational_resources': 121},
#  '2010-12': {'optimistic_speculation': 2,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 5,
#   'bitcoin_technology': 48,
#   'bitcoin_challenges': 23,
#   'altcoins': 3,
#   'educational_resources': 54},
#  '2011-01': {'optimistic_speculation': 1,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 3,
#   'bitcoin_technology': 40,
#   'bitcoin_challenges': 14,
#   'altcoins': 3,
#   'educational_resources': 50},
#  '2024-01': {'optimistic_speculation': 50,
#   'pessimistic_speculation': 12,
#   'bitcoin_adoption': 28,
#   'bitcoin_technology': 63,
#   'bitcoin_challenges': 48,
#   'altcoins': 12,
#   'educational_resources': 125},
#  '2024-02': {'optimistic_speculation': 34,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 13,
#   'bitcoin_technology': 41,
#   'bitcoin_challenges': 46,
#   'altcoins': 9,
#   'educational_resources': 87},
#  '2024-03': {'optimistic_speculation': 32,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 8,
#   'bitcoin_technology': 28,
#   'bitcoin_challenges': 22,
#   'altcoins': 6,
#   'educational_resources': 53},
#  '2011-11': {'optimistic_speculation': 3,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 25,
#   'bitcoin_technology': 58,
#   'bitcoin_challenges': 57,
#   'altcoins': 4,
#   'educational_resources': 93},
#  '2011-12': {'optimistic_speculation': 2,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 26,
#   'bitcoin_technology': 42,
#   'bitcoin_challenges': 34,
#   'altcoins': 3,
#   'educational_resources': 89},
#  '2012-01': {'optimistic_speculation': 6,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 22,
#   'bitcoin_technology': 65,
#   'bitcoin_challenges': 51,
#   'altcoins': 6,
#   'educational_resources': 85},
#  '2012-02': {'optimistic_speculation': 2,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 20,
#   'bitcoin_technology': 48,
#   'bitcoin_challenges': 46,
#   'altcoins': 1,
#   'educational_resources': 70},
#  '2012-03': {'optimistic_speculation': 5,
#   'pessimistic_speculation': 4,
#   'bitcoin_adoption': 24,
#   'bitcoin_technology': 74,
#   'bitcoin_challenges': 40,
#   'altcoins': 6,
#   'educational_resources': 95},
#  '2012-04': {'optimistic_speculation': 2,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 27,
#   'bitcoin_technology': 54,
#   'bitcoin_challenges': 26,
#   'altcoins': 2,
#   'educational_resources': 83},
#  '2012-05': {'optimistic_speculation': 3,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 14,
#   'bitcoin_technology': 90,
#   'bitcoin_challenges': 37,
#   'altcoins': 2,
#   'educational_resources': 107},
#  '2012-06': {'optimistic_speculation': 7,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 19,
#   'bitcoin_technology': 80,
#   'bitcoin_challenges': 36,
#   'altcoins': 1,
#   'educational_resources': 120},
#  '2012-07': {'optimistic_speculation': 3,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 20,
#   'bitcoin_technology': 89,
#   'bitcoin_challenges': 37,
#   'altcoins': 4,
#   'educational_resources': 111},
#  '2011-02': {'optimistic_speculation': 7,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 11,
#   'bitcoin_technology': 58,
#   'bitcoin_challenges': 27,
#   'altcoins': 6,
#   'educational_resources': 76},
#  '2012-08': {'optimistic_speculation': 4,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 17,
#   'bitcoin_technology': 57,
#   'bitcoin_challenges': 40,
#   'altcoins': 0,
#   'educational_resources': 78},
#  '2012-09': {'optimistic_speculation': 5,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 21,
#   'bitcoin_technology': 79,
#   'bitcoin_challenges': 80,
#   'altcoins': 2,
#   'educational_resources': 94},
#  '2012-10': {'optimistic_speculation': 1,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 16,
#   'bitcoin_technology': 41,
#   'bitcoin_challenges': 39,
#   'altcoins': 1,
#   'educational_resources': 66},
#  '2012-11': {'optimistic_speculation': 2,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 23,
#   'bitcoin_technology': 32,
#   'bitcoin_challenges': 20,
#   'altcoins': 3,
#   'educational_resources': 70},
#  '2012-12': {'optimistic_speculation': 1,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 11,
#   'bitcoin_technology': 45,
#   'bitcoin_challenges': 22,
#   'altcoins': 2,
#   'educational_resources': 62},
#  '2013-01': {'optimistic_speculation': 5,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 19,
#   'bitcoin_technology': 53,
#   'bitcoin_challenges': 22,
#   'altcoins': 1,
#   'educational_resources': 79},
#  '2013-02': {'optimistic_speculation': 7,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 31,
#   'bitcoin_technology': 88,
#   'bitcoin_challenges': 56,
#   'altcoins': 2,
#   'educational_resources': 102},
#  '2013-03': {'optimistic_speculation': 22,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 40,
#   'bitcoin_technology': 150,
#   'bitcoin_challenges': 132,
#   'altcoins': 10,
#   'educational_resources': 170},
#  '2013-04': {'optimistic_speculation': 44,
#   'pessimistic_speculation': 22,
#   'bitcoin_adoption': 78,
#   'bitcoin_technology': 170,
#   'bitcoin_challenges': 210,
#   'altcoins': 19,
#   'educational_resources': 294},
#  '2011-03': {'optimistic_speculation': 3,
#   'pessimistic_speculation': 0,
#   'bitcoin_adoption': 10,
#   'bitcoin_technology': 97,
#   'bitcoin_challenges': 44,
#   'altcoins': 3,
#   'educational_resources': 130},
#  '2013-05': {'optimistic_speculation': 12,
#   'pessimistic_speculation': 6,
#   'bitcoin_adoption': 58,
#   'bitcoin_technology': 182,
#   'bitcoin_challenges': 165,
#   'altcoins': 26,
#   'educational_resources': 234},
#  '2013-06': {'optimistic_speculation': 9,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 31,
#   'bitcoin_technology': 126,
#   'bitcoin_challenges': 92,
#   'altcoins': 9,
#   'educational_resources': 175},
#  '2013-07': {'optimistic_speculation': 4,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 35,
#   'bitcoin_technology': 84,
#   'bitcoin_challenges': 78,
#   'altcoins': 18,
#   'educational_resources': 125},
#  '2013-08': {'optimistic_speculation': 3,
#   'pessimistic_speculation': 1,
#   'bitcoin_adoption': 38,
#   'bitcoin_technology': 79,
#   'bitcoin_challenges': 62,
#   'altcoins': 5,
#   'educational_resources': 133},
#  '2011-04': {'optimistic_speculation': 8,
#   'pessimistic_speculation': 5,
#   'bitcoin_adoption': 17,
#   'bitcoin_technology': 97,
#   'bitcoin_challenges': 74,
#   'altcoins': 7,
#   'educational_resources': 134},
#  '2013-09': {'optimistic_speculation': 6,
#   'pessimistic_speculation': 3,
#   'bitcoin_adoption': 22,
#   'bitcoin_technology': 74,
#   'bitcoin_challenges': 68,
#   'altcoins': 7,
#   'educational_resources': 93},
#  '2013-10': {'optimistic_speculation': 8,
#   'pessimistic_speculation': 2,
#   'bitcoin_adoption': 29,
#   'bitcoin_technology': 50,
#   'bitcoin_challenges': 48,
#   'altcoins': 7,
#   'educational_resources': 86},
#  '2013-11': {'optimistic_speculation': 41,
#   'pessimistic_speculation': 8,
#   'bitcoin_adoption': 71,
#   'bitcoin_technology': 187,
#   'bitcoin_challenges': 200,
#   'altcoins': 37,
#   'educational_resources': 267},
#  '2013-12': {'optimistic_speculation': 51,
#   'pessimistic_speculation': 20,
#   'bitcoin_adoption': 128,
#   'bitcoin_technology': 183,
#   'bitcoin_challenges': 217,
#   'altcoins': 30,
#   'educational_resources': 314},
#  '2014-01': {'optimistic_speculation': 35,
#   'pessimistic_speculation': 14,
#   'bitcoin_adoption': 131,
#   'bitcoin_technology': 204,
#   'bitcoin_challenges': 170,
#   'altcoins': 46,
#   'educational_resources': 321},
#  '2014-02': {'optimistic_speculation': 43,
#   'pessimistic_speculation': 17,
#   'bitcoin_adoption': 87,
#   'bitcoin_technology': 218,
#   'bitcoin_challenges': 332,
#   'altcoins': 43,
#   'educational_resources': 330},
#  '2014-03': {'optimistic_speculation': 32,
#   'pessimistic_speculation': 13,
#   'bitcoin_adoption': 81,
#   'bitcoin_technology': 198,
#   'bitcoin_challenges': 225,
#   'altcoins': 34,
#   'educational_resources': 321},
#  '2014-04': {'optimistic_speculation': 25,
#   'pessimistic_speculation': 13,
#   'bitcoin_adoption': 86,
#   'bitcoin_technology': 157,
#   'bitcoin_challenges': 162,
#   'altcoins': 39,
#   'educational_resources': 267},
#  '2014-05': {'optimistic_speculation': 34,
#   'pessimistic_speculation': 11,
#   'bitcoin_adoption': 95,
#   'bitcoin_technology': 117,
#   'bitcoin_challenges': 153,
#   'altcoins': 21,
#   'educational_resources': 214},
#  '2014-06': {'optimistic_speculation': 35,
#   'pessimistic_speculation': 7,
#   'bitcoin_adoption': 98,
#   'bitcoin_technology': 126,
#   'bitcoin_challenges': 141,
#   'altcoins': 19,
#   'educational_resources': 168},
#  '2014-07': {'optimistic_speculation': 39,
#   'pessimistic_speculation': 8,
#   'bitcoin_adoption': 113,
#   'bitcoin_technology': 141,
#   'bitcoin_challenges': 145,
#   'altcoins': 24,
#   'educational_resources': 234},
#  '2014-08': {'optimistic_speculation': 26,
#   'pessimistic_speculation': 13,
#   'bitcoin_adoption': 89,
#   'bitcoin_technology': 115,
#   'bitcoin_challenges': 114,
#   'altcoins': 19,
#   'educational_resources': 194},
#  '2014-09': {'optimistic_speculation': 24,
#   'pessimistic_speculation': 15,
#   'bitcoin_adoption': 103,
#   'bitcoin_technology': 110,
#   'bitcoin_challenges': 124,
#   'altcoins': 23,
#   'educational_resources': 183}}

# %%
df = pd.DataFrame(columns=["month"] + categories)
for month in months:
    row = {"month": month}
    for category in categories:
        row[category] = months[month][category]
    df = pd.concat([df, pd.DataFrame([row])])

df = df.sort_values(by="month")
df = df.reset_index(drop=True)

# get the number of posts for each month
posts_count = df[categories].sum(axis=1)

# %%
posts_count = posts_count.reset_index(drop=True)

# %%
df["posts_count"] = posts_count

# %%
df.to_csv('raw_values.csv', index=False)

# %%
# Obtain a categorical distribution for each month
for index, row in df.iterrows():
    total = sum(df.loc[index, category] for category in categories)
    # print(total)
    for category in categories:
        df.loc[index, category] = df.loc[index, category] / total


df.to_csv('normalized_values.csv', index=False)

# %%
df
# Out:
#        month optimistic_speculation pessimistic_speculation bitcoin_adoption  \
# 0    2010-01                    0.0                     0.0              0.0
# 1    2010-02                    0.0                     0.0              0.0
# 2    2010-03                    0.0                     0.0         0.090909
# 3    2010-04                    0.0                     0.0              0.0
# 4    2010-05                    0.0                     0.0             0.25
# ..       ...                    ...                     ...              ...
# 166  2023-11               0.145897                0.015198         0.069909
# 167  2023-12               0.139276                0.033426         0.066852
# 168  2024-01               0.147929                0.035503          0.08284
# 169  2024-02               0.147186                0.004329         0.056277
# 170  2024-03               0.205128                0.044872         0.051282
#
#     bitcoin_technology bitcoin_challenges  altcoins educational_resources  \
# 0                  0.4           0.066667       0.0              0.533333
# 1             0.473684           0.052632       0.0              0.473684
# 2             0.363636           0.090909       0.0              0.454545
# 3             0.333333               0.25  0.083333              0.333333
# 4                  0.0               0.25       0.0                   0.5
# ..                 ...                ...       ...                   ...
# 166           0.197568           0.194529  0.036474              0.340426
# 167           0.192201           0.175487   0.05571              0.337047
# 168           0.186391           0.142012  0.035503              0.369822
# 169           0.177489           0.199134  0.038961              0.376623
# 170           0.179487           0.141026  0.038462              0.339744
#
#     posts_count
# 0            15
# 1            19
# 2            11
# 3            12
# 4             4
# ..          ...
# 166         329
# 167         359
# 168         338
# 169         231
# 170         156
#
# [171 rows x 9 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[categories+["posts_count"]] = scaler.fit_transform(df[categories+["posts_count"]])
df.rename(columns={"month":"date"}, inplace=True)
df.to_csv('general.csv', index=False)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

df = pd.read_csv('normalized_values.csv')
df["month"] = pd.to_datetime(df["month"])
df = df.set_index("month")

# make a plot for each category

for category in categories+["posts_count"]:
    fig, ax = plt.subplots()
    ax.plot(df.index, df[category])
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    ax.xaxis.set_tick_params(rotation=30)
    ax.set_title(category)
    plt.show()
